# %%
#!/usr/bin/env python

import json
import shutil
import os
from collections import namedtuple
from ansible.parsing.dataloader import DataLoader
from ansible.vars.manager import VariableManager
from ansible.inventory.manager import InventoryManager
from ansible.playbook.play import Play
from ansible.executor.task_queue_manager import TaskQueueManager
from ansible.plugins.callback import CallbackBase
from ansible.executor.playbook_executor import PlaybookExecutor
import ansible.constants as C


class ResultCallback(CallbackBase):
    """A sample callback plugin used for performing an action as results come in

    If you want to collect all results into a single object for processing at
    the end of the execution, look into utilizing the ``json`` callback plugin
    or writing your own custom callback plugin
    """
    def v2_runner_on_ok(self, result, **kwargs):
        """Print a json representation of the result

        This method could store the result in an instance attribute for retrieval later
        """
        host = result._host
        print(json.dumps({host.name: result._result}, indent=4))

# %%
variable_manager = VariableManager(loader=loader, inventory=inventory)
loader = DataLoader()

#put file path of inventory file inside sources
inventory = InventoryManager(loader=loader, sources=['inventory'])
playbook_path = 'term.yml'

#print out hosts under type 'dns'
print(inventory.get_groups_dict()['dns'])
if not os.path.exists(playbook_path):
    print '[INFO] The playbook does not exist'
    sys.exit()
#had to add 'diff' into named tuple & diff=false into Options
Options = namedtuple('Options', ['listtags', 'listtasks', 'listhosts', 'syntax', 'connection','module_path', 'forks', 'remote_user', 'private_key_file', 'ssh_common_args', 'ssh_extra_args', 'sftp_extra_args', 'scp_extra_args', 'become', 'become_method', 'become_user', 'verbosity', 'check', 'diff'])
options = Options(listtags=False, listtasks=False, listhosts=False, syntax=False, connection='paramiko', module_path=None, forks=100, remote_user='tbo2', private_key_file=None, ssh_common_args=None, ssh_extra_args=None, sftp_extra_args=None, scp_extra_args=None, become=True, become_method=None, become_user=None, verbosity=None, check=False, diff=False)

#variable_manager.extra_vars = {'hosts': 'dns'} # This can accomodate various other command line arguments.`

passwords = {}

pbex = PlaybookExecutor(playbooks=[playbook_path], inventory=inventory, variable_manager=variable_manager, loader=loader, options=options, passwords=passwords)

results = pbex.run()
# Out:
# [u'zk']
# ---------------------------------------------------------------------------
# AnsibleParserError                        Traceback (most recent call last)
# <ipython-input-68-9fced09bdd31> in <module>()
#      21 pbex = PlaybookExecutor(playbooks=[playbook_path], inventory=inventory, variable_manager=variable_manager, loader=loader, options=options, passwords=passwords)
#      22
# ---> 23 results = pbex.run()
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/executor/playbook_executor.pyc in run(self)
#      79         try:
#      80             for playbook_path in self._playbooks:
# ---> 81                 pb = Playbook.load(playbook_path, variable_manager=self._variable_manager, loader=self._loader)
#      82                 # FIXME: move out of inventory self._inventory.set_playbook_basedir(os.path.realpath(os.path.dirname(playbook_path)))
#      83
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/__init__.pyc in load(file_name, variable_manager, loader)
#      52     def load(file_name, variable_manager=None, loader=None):
#      53         pb = Playbook(loader=loader)
# ---> 54         pb._load_playbook_data(file_name=file_name, variable_manager=variable_manager)
#      55         return pb
#      56
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/__init__.pyc in _load_playbook_data(self, file_name, variable_manager)
#     104                     display.display("skipping playbook '%s' due to conditional test failure" % which, color=C.COLOR_SKIP)
#     105             else:
# --> 106                 entry_obj = Play.load(entry, variable_manager=variable_manager, loader=self._loader)
#     107                 self._entries.append(entry_obj)
#     108
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/play.pyc in load(data, variable_manager, loader)
#     109                 data['name'] = data['hosts']
#     110         p = Play()
# --> 111         return p.load_data(data, variable_manager=variable_manager, loader=loader)
#     112
#     113     def preprocess_data(self, ds):
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/base.pyc in load_data(self, ds, variable_manager, loader)
#     256                 method = getattr(self, '_load_%s' % name, None)
#     257                 if method:
# --> 258                     self._attributes[target_name] = method(name, ds[name])
#     259                 else:
#     260                     self._attributes[target_name] = ds[name]
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/play.pyc in _load_tasks(self, attr, ds)
#     140         '''
#     141         try:
# --> 142             return load_list_of_blocks(ds=ds, play=self, variable_manager=self._variable_manager, loader=self._loader)
#     143         except AssertionError as e:
#     144             raise AnsibleParserError("A malformed block was encountered while loading tasks", obj=self._ds, orig_exc=e)
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/helpers.pyc in load_list_of_blocks(ds, play, parent_block, role, task_include, use_handlers, variable_manager, loader)
#      78                             use_handlers=use_handlers,
#      79                             variable_manager=variable_manager,
# ---> 80                             loader=loader,
#      81                         )
#      82                     )
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/block.pyc in load(data, play, parent_block, role, task_include, use_handlers, variable_manager, loader)
#      87         implicit = not Block.is_block(data)
#      88         b = Block(play=play, parent_block=parent_block, role=role, task_include=task_include, use_handlers=use_handlers, implicit=implicit)
# ---> 89         return b.load_data(data, variable_manager=variable_manager, loader=loader)
#      90
#      91     @staticmethod
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/base.pyc in load_data(self, ds, variable_manager, loader)
#     256                 method = getattr(self, '_load_%s' % name, None)
#     257                 if method:
# --> 258                     self._attributes[target_name] = method(name, ds[name])
#     259                 else:
#     260                     self._attributes[target_name] = ds[name]
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/block.pyc in _load_block(self, attr, ds)
#     123                 variable_manager=self._variable_manager,
#     124                 loader=self._loader,
# --> 125                 use_handlers=self._use_handlers,
#     126             )
#     127         except AssertionError as e:
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/helpers.pyc in load_list_of_tasks(ds, play, block, role, task_include, use_handlers, variable_manager, loader)
#     342                     t = Handler.load(task_ds, block=block, role=role, task_include=task_include, variable_manager=variable_manager, loader=loader)
#     343                 else:
# --> 344                     t = Task.load(task_ds, block=block, role=role, task_include=task_include, variable_manager=variable_manager, loader=loader)
#     345
#     346                 task_list.append(t)
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/task.pyc in load(data, block, role, task_include, variable_manager, loader)
#     140     def load(data, block=None, role=None, task_include=None, variable_manager=None, loader=None):
#     141         t = Task(block=block, role=role, task_include=task_include)
# --> 142         return t.load_data(data, variable_manager=variable_manager, loader=loader)
#     143
#     144     def __repr__(self):
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/base.pyc in load_data(self, ds, variable_manager, loader)
#     243         # something we can more easily parse, and then call the validation
#     244         # function on it to ensure there are no incorrect key values
# --> 245         ds = self.preprocess_data(ds)
#     246         self._validate_attributes(ds)
#     247
#
# /Users/tbo2/anaconda2/envs/delawarepj/lib/python2.7/site-packages/ansible/playbook/task.pyc in preprocess_data(self, ds)
#     185             (action, args, delegate_to) = args_parser.parse()
#     186         except AnsibleParserError as e:
# --> 187             raise AnsibleParserError(to_native(e), obj=ds, orig_exc=e)
#     188
#     189         # the command/shell/script modules used to support the `cmd` arg,
#
# AnsibleParserError: unexpected parameter type in action: <class 'ansible.parsing.yaml.objects.AnsibleSequence'>
#
# The error appears to have been in '/Users/tbo2/Documents/programming/AWX/ansible-module/delawarepj/ansible/term.yml': line 19, column 7, but may
# be elsewhere in the file depending on the exact syntax problem.
#
# The offending line appears to be:
#
#
#     - name: telnet into termserver
#       ^ here
#
#
# The error appears to have been in '/Users/tbo2/Documents/programming/AWX/ansible-module/delawarepj/ansible/term.yml': line 19, column 7, but may
# be elsewhere in the file depending on the exact syntax problem.
#
# The offending line appears to be:
#
#
#     - name: telnet into termserver
#       ^ here
